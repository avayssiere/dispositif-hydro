# %%
import os
import pandas as pd
import numpy as np

data_folder = os.path.join("data", "Bigny")
os.listdir(data_folder)
# Out:
# ['Pre_Martial_modele.xlsx',
#  'Arnet_modele.xlsx',
#  'Le_cher_modele.xlsx',
#  'Site de Bigny.docx',
#  'LP1_modele.xlsx',
#  'Chevalier_modele.xlsx']

# %%
q_m3s_SAM = pd.read_excel(os.path.join("data", "StA_d\x82bit_2015-2018.xlsx"), skiprows=1, index_col=2)
q_m3s_SAM.set_index(pd.to_datetime(q_m3s_SAM.index), inplace=True)
# q_m3s_SAM = q_m3s_SAM.loc[:, "Debit en m3/s"]
q_m3s_SAM.drop("NaT", inplace=True)

q_m3s_SAM.head()
# Out:
#                                     Date  Heure Debit en m3/s
# date_heure
# 2015-01-01 00:00:00  2015-01-01 00:00:00  00:00          57.3
# 2015-01-03 02:35:00  2015-01-03 00:00:00  02:35          52.5
# 2015-01-04 00:21:00  2015-01-04 00:00:00  00:21          47.9
# 2015-01-04 11:56:00  2015-01-04 00:00:00  11:56          46.5
# 2015-01-04 18:12:00  2015-01-04 00:00:00  18:12          47.7

# %%
pre_martial_df = pd.read_excel(os.path.join(data_folder, "Pre_Martial_modele.xlsx"), skiprows=8, index_col=0)
pre_martial_df.set_index(pd.to_datetime(pre_martial_df.index), inplace=True)
pre_martial_df = pre_martial_df.iloc[:, [0, 1, 2, 5]]
pre_martial_df.head()
# Out:
#                     Charge hydraulique[cm]  Température[°C]  \
# Date/time
# 2015-03-18 17:00:00                  83.15            8.390
# 2015-03-18 17:15:00                 83.375            8.247
# 2015-03-18 17:30:00                 83.375            8.190
# 2015-03-18 17:45:00                   83.1            8.163
# 2015-03-18 18:00:00                   83.2            8.150
#
#                      Profondeur / sol (cm)   Alti NGF
# Date/time
# 2015-03-18 17:00:00                 13.350  141.49650
# 2015-03-18 17:15:00                 13.125  141.49875
# 2015-03-18 17:30:00                 13.125  141.49875
# 2015-03-18 17:45:00                 13.400  141.49600
# 2015-03-18 18:00:00                 13.300  141.49700

# %%
arnet_df = pd.read_excel(os.path.join(data_folder, "Arnet_modele.xlsx"), skiprows=8, index_col=0)
arnet_df.set_index(pd.to_datetime(arnet_df.index), inplace=True)
arnet_df = arnet_df.iloc[:, [0, 1, 2, 5]]
arnet_df.rename(columns={arnet_df.columns[-1]: "Alti NGF"}, inplace=True)
arnet_df.head()
# Out:
#                     Charge hydraulique[cm]  Température[°C]  \
# Date/time
# 2014-11-17 16:00:00                  37.65           13.333
# 2014-11-17 16:15:00                 37.358           13.340
# 2014-11-17 16:30:00                 37.708           13.340
# 2014-11-17 16:45:00                  37.65           13.340
# 2014-11-17 17:00:00                 37.825           13.340
#
#                      Profondeur  eau / sol (cm)   Alti NGF
# Date/time
# 2014-11-17 16:00:00                     426.350  139.74850
# 2014-11-17 16:15:00                     426.642  139.74558
# 2014-11-17 16:30:00                     426.292  139.74908
# 2014-11-17 16:45:00                     426.350  139.74850
# 2014-11-17 17:00:00                     426.175  139.75025

# %%
le_cher_df = pd.read_excel(os.path.join(data_folder, "Le_cher_modele.xlsx"), skiprows=8, index_col=0)
le_cher_df.set_index(pd.to_datetime(le_cher_df.index), inplace=True)
le_cher_df = le_cher_df.iloc[:, [0, 1, 2, 5]]
le_cher_df.rename(columns={le_cher_df.columns[-1]: "Alti NGF"}, inplace=True)
le_cher_df.head()
# Out:
#                     Charge hydraulique[cm]  Température[°C]  \
# Date/time
# 2015-04-29 12:00:00                142.583           12.643
# 2015-04-29 12:15:00                142.033           12.643
# 2015-04-29 12:30:00                142.258           12.650
# 2015-04-29 12:45:00                142.258           12.650
# 2015-04-29 13:00:00                141.958           12.657
#
#                      Profondeur  eau / sol (cm)   Alti NGF
# Date/time
# 2015-04-29 12:00:00                      90.417  139.24583
# 2015-04-29 12:15:00                      90.967  139.24033
# 2015-04-29 12:30:00                      90.742  139.24258
# 2015-04-29 12:45:00                      90.742  139.24258
# 2015-04-29 13:00:00                      91.042  139.23958

# %%
lp1_df = pd.read_excel(os.path.join(data_folder, "LP1_modele.xlsx"), skiprows=8, index_col=0)
lp1_df.set_index(pd.to_datetime(lp1_df.index), inplace=True)
lp1_df = lp1_df.iloc[:, [0, 1, 2, 5]]
lp1_df.rename(columns={lp1_df.columns[-1]: "Alti NGF"}, inplace=True)
lp1_df.head()
# Out:
#                     Charge hydraulique[cm]  Température[°C]  \
# Date/time
# 2014-11-17 16:00:00                   37.3           13.883
# 2014-11-17 16:15:00                   37.3           13.883
# 2014-11-17 16:30:00                 37.767           13.883
# 2014-11-17 16:45:00                 37.883           13.883
# 2014-11-17 17:00:00                 37.767           13.883
#
#                      Profondeur  eau / sol (cm)   Alti NGF
# Date/time
# 2014-11-17 16:00:00                     147.700  139.32300
# 2014-11-17 16:15:00                     147.700  139.32300
# 2014-11-17 16:30:00                     147.233  139.32767
# 2014-11-17 16:45:00                     147.117  139.32883
# 2014-11-17 17:00:00                     147.233  139.32767

# %%
chevalier_df = pd.read_excel(os.path.join(data_folder, "Chevalier_modele.xlsx"), skiprows=8, index_col=0)
chevalier_df.set_index(pd.to_datetime(chevalier_df.index), inplace=True)
chevalier_df = chevalier_df.iloc[:, [0, 1, 2, 5]]
chevalier_df.rename(columns={chevalier_df.columns[-1]: "Alti NGF"}, inplace=True)
chevalier_df.head()
# Out:
#                     Charge hydraulique[cm]  Température[°C]  \
# Date/time
# 2015-01-21 16:00:00                111.842           12.113
# 2015-01-21 16:15:00                112.017           12.113
# 2015-01-21 16:30:00                112.017           12.113
# 2015-01-21 16:45:00                112.017           12.100
# 2015-01-21 17:00:00                112.017           12.113
#
#                      Profondeur  eau / sol (cm)   Alti NGF
# Date/time
# 2015-01-21 16:00:00                     254.158  139.83842
# 2015-01-21 16:15:00                     253.983  139.84017
# 2015-01-21 16:30:00                     253.983  139.84017
# 2015-01-21 16:45:00                     253.983  139.84017
# 2015-01-21 17:00:00                     253.983  139.84017

# %%
meteo_orval = pd.read_excel(os.path.join("data", "m\x82t\x82o_orval.xlsx"), index_col=1)
meteo_orval.set_index(pd.to_datetime(meteo_orval.index), inplace=True)
meteo_orval = meteo_orval.iloc[:, [1, 3]]
meteo_orval.rename(columns={"RR-précipitation (mm)": "RR(mm)","TM -Température (C°)": "TM(C°)"}, inplace=True)
meteo_orval.head()
# Out:
#             RR(mm)  TM(C°)
# DATE
# 2014-11-01     0.2    14.1
# 2014-11-02     9.3    13.8
# 2014-11-03     8.1    14.6
# 2014-11-04     1.4     9.2
# 2014-11-05     0.2     7.3

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

plt.figure(figsize=(9, 6))

for name, df in {"PRE MARTIAL": pre_martial_df, "ARNET": arnet_df, "LE CHER": le_cher_df, "LP1": lp1_df, "CHEVALIER": chevalier_df}.items():
    df = df.dropna()
    plt.plot(df["Température[°C]"], alpha=0.75, label=name)

plt.plot(meteo_orval["TM(C°)"], color="black", alpha=0.2)
    
plt.ylabel("Temperature [deg.C]")
plt.title("Temperature evolution of different sensors of the Bigny study area")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="899.2500000000001">

# %%
plt.figure(figsize=(9, 6))

for name, df in {"PRE MARTIAL": pre_martial_df, "ARNET": arnet_df, "LE CHER": le_cher_df, "LP1": lp1_df, "CHEVALIER": chevalier_df}.items():
    df = df.dropna()
    plt.plot(df["Alti NGF"], '-', alpha=0.75, label=name)    

plt.ylabel("Altitude [m]")
plt.title("Evolution of the water table level for different sensors of the Bigny study area")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="899.2500000000001">

# %%
fig, ax1 = plt.subplots(figsize=(9, 6))

for name, df in {"PRE MARTIAL": pre_martial_df, "ARNET": arnet_df, "LE CHER": le_cher_df, "LP1": lp1_df, "CHEVALIER": chevalier_df}.items():
    df = df.dropna()
    ax1.plot(df["Alti NGF"], '-', alpha=0.75, label=name) 

ax2 = ax1.twinx()
ax2.plot(q_m3s_SAM["Debit en m3/s"], "-", color="black", alpha=0.2)

ax1.set_ylabel("Altitude [m]")
ax1.legend()

ax2.set_ylabel("Discharge [m3/s]", color='grey')
ax2.tick_params('y', colors='grey')
plt.title("Evolution of the water table level for different sensors of the Bigny study area")
# Out:
# <img src="data:image/png;base64,..." width="899.2500000000001">
# Text(0.5,1,'Evolution of the water table level for different sensors of the Bigny study area')

# %%
plt.figure(figsize=(9, 6))
plt.plot(q_m3s_SAM["Debit en m3/s"], "-", color="black", alpha=0.9)
# Out:
# <img src="data:image/png;base64,..." width="899.2500000000001">

# %%
fig, ax1 = plt.subplots(figsize=(9, 6))

for name, df in {"PRE MARTIAL": pre_martial_df, "ARNET": arnet_df, "LE CHER": le_cher_df, "LP1": lp1_df, "CHEVALIER": chevalier_df}.items():
    df = df.dropna()
    ax1.plot(df["Alti NGF"], '-', alpha=0.75, label=name) 

ax2 = ax1.twinx()
ax2.plot(meteo_orval["RR(mm)"], "-", color="black", alpha=0.2)

ax1.set_ylabel("Altitude [m]")
ax1.legend(loc=2)

ax2.set_ylabel("Rain fall precipitation [mm]", color='grey')
ax2.tick_params('y', colors='grey')
plt.title("Evolution of the water table level for different sensors of the Bigny study area")
# Out:
# <img src="data:image/png;base64,..." width="899.2500000000001">
# Text(0.5,1,'Evolution of the water table level for different sensors of the Bigny study area')

# %%
data_dict = {"PRE MARTIAL": pre_martial_df.dropna(), "ARNET": arnet_df.dropna(), "LE CHER": le_cher_df.dropna(), "LP1": lp1_df.dropna(), "CHEVALIER": chevalier_df.dropna()}

to_plot = [df["Alti NGF"].values.tolist() for _, df in data_dict.items()]

plt.figure(figsize=(9, 6))
plt.boxplot(to_plot)

plt.xticks(range(1, 6), data_dict.keys())
plt.savefig('moustaches.png', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="899.2500000000001">

# %% [markdown]
# ### Temperatures correlations

# %%
dict_df = {"PRE MARTIAL": pre_martial_df, "ARNET": arnet_df, "LE CHER": le_cher_df, "LP1": lp1_df, "CHEVALIER": chevalier_df}

frames = {k: df["Température[°C]"].loc[~df.index.duplicated(keep='first')] for k, df in dict_df.items()}
temp = pd.concat(frames, axis=1)

# %%
tem_corr = temp.corr()
tem_corr
# Out:
#                 ARNET  CHEVALIER   LE CHER       LP1  PRE MARTIAL
# ARNET        1.000000   0.796169  0.480080  0.714592     0.760537
# CHEVALIER    0.796169   1.000000  0.509796  0.978889     0.883467
# LE CHER      0.480080   0.509796  1.000000  0.507386     0.809691
# LP1          0.714592   0.978889  0.507386  1.000000     0.910312
# PRE MARTIAL  0.760537   0.883467  0.809691  0.910312     1.000000

# %%
tem_corr_val = np.round(tem_corr.values, 2)

# %%
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)
im = ax.matshow(tem_corr_val, cmap=plt.cm.viridis_r, alpha=0.5)

labels = temp.corr().columns.tolist()
ax.set_xticklabels([""]+labels)
ax.set_yticklabels([""]+labels)

for i in range(5):
    for j in range(5):
        ax.text(i, j, round(tem_corr_val[i, j], 3), color='black', ha='center', va='center')
# Out:
# <img src="data:image/png;base64,..." width="599.5">

# %% [markdown]
# ### Water table level correlation

# %%
dict_df = {"PRE MARTIAL": pre_martial_df, "ARNET": arnet_df, "LE CHER": le_cher_df, "LP1": lp1_df, "CHEVALIER": chevalier_df}

frames = {k: df["Alti NGF"].loc[~df.index.duplicated(keep='first')] for k, df in dict_df.items()}
alt = pd.concat(frames, axis=1)

# %%
alt_corr = alt.corr()
alt_corr
# Out:
#                 ARNET  CHEVALIER   LE CHER       LP1  PRE MARTIAL
# ARNET        1.000000   0.972637  0.607704  0.981845     0.879365
# CHEVALIER    0.972637   1.000000  0.572169  0.983738     0.937564
# LE CHER      0.607704   0.572169  1.000000  0.639119     0.628961
# LP1          0.981845   0.983738  0.639119  1.000000     0.937902
# PRE MARTIAL  0.879365   0.937564  0.628961  0.937902     1.000000

# %%
alt_corr_val = np.round(alt_corr.values, 2)

# %%
fig = plt.figure(figsize=(6, 5))
ax = fig.add_subplot(111)
im = ax.matshow(alt_corr_val, cmap=plt.cm.viridis_r, alpha=0.5)

labels = alt_corr.columns.tolist()
ax.set_xticklabels([""]+labels)
ax.set_yticklabels([""]+labels)

for i in range(5):
    for j in range(5):
        ax.text(i, j, round(alt_corr_val[i, j], 3), color='black', ha='center', va='center')
# Out:
# <img src="data:image/png;base64,..." width="599.5">

# %% [markdown]
# * color to correlation
# * autre site
# * corr to QStAmandSelles2.txt

# %%
cc = alt.rolling("7D").corr(pairwise=True)
cc.head(10)
# Out:
#                                  ARNET  CHEVALIER  LE CHER  LP1  PRE MARTIAL
# Date/time
# 2014-11-17 16:00:00 ARNET          NaN        NaN      NaN  NaN          NaN
#                     CHEVALIER      NaN        NaN      NaN  NaN          NaN
#                     LE CHER        NaN        NaN      NaN  NaN          NaN
#                     LP1            NaN        NaN      NaN  NaN          NaN
#                     PRE MARTIAL    NaN        NaN      NaN  NaN          NaN
# 2014-11-17 16:15:00 ARNET          1.0        NaN      NaN  NaN          NaN
#                     CHEVALIER      NaN        NaN      NaN  NaN          NaN
#                     LE CHER        NaN        NaN      NaN  NaN          NaN
#                     LP1            NaN        NaN      NaN  NaN          NaN
#                     PRE MARTIAL    NaN        NaN      NaN  NaN          NaN

# %%
plt.figure(figsize=(9, 6))

plt.plot(alt.index, cc.xs("ARNET", level=1, drop_level=False)["LE CHER"])
plt.plot(alt.index, cc.xs("CHEVALIER", level=1, drop_level=False)["LE CHER"])
plt.plot(alt.index, cc.xs("LP1", level=1, drop_level=False)["LE CHER"])
plt.plot(alt.index, cc.xs("PRE MARTIAL", level=1, drop_level=False)["LE CHER"])

plt.ylim(0, 1)
# Out:
# <img src="data:image/png;base64,..." width="899.2500000000001">
# (0, 1)

# %%
from sklearn import preprocessing

# %%
end = 30
results = {}
temp_to_shift = temp.copy().resample("1D").mean()
temp_to_shift.dropna(inplace=True)

for col in temp_to_shift.columns:
    min_max_scaler = preprocessing.MinMaxScaler()
    temp_to_shift[col] = min_max_scaler.fit_transform(temp_to_shift[col].values.reshape(-1, 1))

for i in range(1, end):
    temp_to_shift = temp_to_shift.shift(1)
    results[i] = pd.concat([temp_to_shift, meteo_orval["TM(C°)"]], axis=1).corr()["TM(C°)"]

results[10]
# Out:
# ARNET          0.323872
# CHEVALIER      0.279743
# LE CHER        0.822520
# LP1            0.315850
# PRE MARTIAL    0.627841
# TM(C°)         1.000000
# Name: TM(C°), dtype: float64

# %%
res_corr = {k: v.drop("TM(C°)").to_dict() for k, v in results.items()}
res_corr_df = pd.DataFrame().from_dict(res_corr, orient="index")
res_corr_df.head()
# Out:
#       ARNET  CHEVALIER   LE CHER       LP1  PRE MARTIAL
# 1  0.465987   0.423232  0.898913  0.434409     0.705287
# 2  0.446820   0.404068  0.878048  0.421014     0.695988
# 3  0.429772   0.386549  0.863785  0.408134     0.687284
# 4  0.413666   0.369695  0.854658  0.394887     0.678680
# 5  0.399841   0.354281  0.848443  0.382262     0.670554

# %%
plt.figure(figsize=(9, 6))

for col in res_corr_df.columns:
    plt.plot(res_corr_df[col], '-', label=col, alpha=0.75)
# Out:
# <img src="data:image/png;base64,..." width="899.2500000000001">

# %% [markdown]
# normalizer par les précipitation ou températures ?

# %%
plt.figure(figsize=(9, 6))

for name, df in {"PRE MARTIAL": pre_martial_df, "ARNET": arnet_df, "LE CHER": le_cher_df, "LP1": lp1_df, "CHEVALIER": chevalier_df}.items():
    df = df.dropna().rolling(4*24*30, center=True).mean()
    plt.plot(df["Température[°C]"],  alpha=0.75, label=name)

plt.plot(meteo_orval["TM(C°)"], alpha=0.2)
    
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="899.2500000000001">
